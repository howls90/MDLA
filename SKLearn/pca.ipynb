# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/howls/.local/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning:
#
# pylab import has clobbered these variables: ['Figure', 'Annotation']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from sklearn.datasets import load_digits
digits = load_digits()
x, y = digits.data, digits.target

# %%
print(digits.keys())
# Out:
# dict_keys(['data', 'target_names', 'target', 'images', 'DESCR'])

# %% [raw]
# def plot_pca_scatter():
#     colors = ['black', 'blue', 'purple', 'yellow', 'white', 'red', 'lime', 'cyan', 'orange', 'gray']
#     for i in range(len(colors)):
#         px = X_pca[:, 0][y_digits == i]
#         py = X_pca[:, 1][y_digits == i]
#         plt.scatter(px, py, c=colors[i])
#     plt.legend(digits.target_names)
#     plt.xlabel('First Principal Component')
#     plt.ylabel('Second Principal Component')

# %%
def plot_pca_scatter():
    colors = ['black', 'blue', 'purple', 'yellow', 'white', 'red', 'lime', 'cyan', 'orange', 'gray']
    for i in range(len(colors)):
        px = X_pca[:, 0][y == i]
        py = X_pca[:, 1][y == i]
        plt.scatter(px, py, c=colors[i])
    plt.legend(digits.target_names)
    plt.xlabel('First Principal Component')
    plt.ylabel('Second Principal Component')
n_row, n_col = 2, 5
from sklearn.decomposition import PCA

n_components = n_row * n_col
estimator = PCA(n_components=n_components)
X_pca = estimator.fit_transform(x)
plot_pca_scatter()

# %%
def print_pca_components(images, n_col, n_row):
    plt.figure(figsize=(2. * n_col, 2.26 * n_row))
    for i, comp in enumerate(images):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(comp.reshape((8, 8)), interpolation='nearest')
        plt.text(0, -1, str(i + 1) + '-component')
        plt.xticks(())
        plt.yticks(())

# %%
print_pca_components(estimator.components_[:n_components], n_col, n_row)
